# %%
import csv, os, time, datetime, geojson
        
siteArr = []

with open('construction-site.xls.csv') as csvFile:
    csvReader = csv.reader(csvFile, delimiter=',')
    lineCount=0
    for row in csvReader:
        if lineCount!=0:
            if row[2]!= "" and row[3]!="":                                
                dateStart = row[8].split("/")
                dateEnd = row[9].split("/")
                if row[8] != "" and row[9] != "":
                    timestamp1 = time.mktime(datetime.datetime.strptime(row[8],"%m/%d/%Y").timetuple())
                    timestamp2 = time.mktime(datetime.datetime.strptime(row[9],"%m/%d/%Y").timetuple())
                    
                    dict = {
                    "bpFrom" : row[2],
                    "bpTo" : row[3],
                    "distanceFrom" : row[4],
                    "distanceTo" : row[5],
                    "startDate" : timestamp1,
                    "endDate" : timestamp2
                    }
                    siteArr.append(dict)
                

        

        lineCount += 1
        
bpArr = []        
        
with open('linie-mit-betriebspunkten.xls.csv') as csvFile:
    csvReader = csv.reader(csvFile, delimiter=',')
    lineCount=0
    for row in csvReader:
        if lineCount!=0:
            if row[2]!= "" and row[10]!="":
                latLng=row[10].split(',')
                dict = {
                    "abbr" : row[2],
                    "Lat" : latLng[1],
                    "Lng" : latLng[0]
                }
                
                bpArr.append(dict)
        lineCount += 1        

newCsv = []
newCsv.append(["bpFrom", "bpTo","geoshape"])
for elem in siteArr:
    bpFromCoord =[]
    bpToCoord = []
    for i in bpArr:
        if i.get("abbr") == elem.get("bpFrom") and i.get("abbr") == elem.get("bpTo"):
            bpToCoord.append(i.get("Lat"))
            bpToCoord.append(i.get("Lng"))
            bpFromCoord.append(i.get("Lat"))
            bpFromCoord.append(i.get("Lng"))
        elif i.get("abbr") == elem.get("bpFrom"):
            bpFromCoord.append(i.get("Lat"))
            bpFromCoord.append(i.get("Lng"))
    for i in bpArr:
        if i.get("abbr") == elem.get("bpTo"):
            bpToCoord.append(i.get("Lat"))
            bpToCoord.append(i.get("Lng"))

    
    if bpFromCoord != [] and bpToCoord != []:
        lineStrings = []
        addCount = int((float(elem.get("endDate")) - float(elem.get("startDate"))) / 10000)
        addLat = (float(bpToCoord[0]) - float(bpFromCoord[0])) / addCount
        addLng = (float(bpToCoord[1]) - float(bpFromCoord[1])) / addCount
        print(addCount)
        for i in range(addCount):
            lineStrings.append((float(bpFromCoord[0]) + i*addLat, float(bpFromCoord[1]) + i*addLat, 0, elem.get("startDate") + 10000*i))                  
        geoJsonObj = geojson.Feature(geometry=geojson.LineString(lineStrings))
        featureCollection = geojson.FeatureCollection([geoJsonObj])
        
        properties_dict = {
            "bpFrom" : elem.get("bpFrom"),
            "bpTo" : elem.get("bpTo"),
        }
        #Convert the dictionary to a list
        properties_list = list(zip(properties_dict.keys(),properties_dict.values()))
        print(properties_list)
        #Loop over GeoJSON features and add the new properties
        for feat in featureCollection['features']:
            for i in range(len(properties_list)):
                feat ['properties'][properties_list[i][0]]=properties_list[i][1]
        
        #print(featureCollection['features'][0])
        newCsv.append([elem.get("bpFrom"), elem.get("bpTo"),featureCollection['features'][0]])
              
        
with open('newConstSite.csv','w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(newCsv)
# Out:
# 4708
# [('bpFrom', 'PUI'), ('bpTo', 'PAL')]
# 6246
# [('bpFrom', 'PU'), ('bpTo', 'CU')]
# 3136
# [('bpFrom', 'MX'), ('bpTo', 'TER')]
# 2410
# [('bpFrom', 'VIL'), ('bpTo', 'MX')]
# 2894
# [('bpFrom', 'BR'), ('bpTo', 'STDG')]
# 4345
# [('bpFrom', 'CHV'), ('bpTo', 'CHV')]
# 3136
# [('bpFrom', 'LHE'), ('bpTo', 'LHE')]
# 9063
# [('bpFrom', 'ZSEB'), ('bpTo', 'ZSEB')]
# 6039
# [('bpFrom', 'ZUE'), ('bpTo', 'ZUE')]
# 10878
# [('bpFrom', 'KLW'), ('bpTo', 'KLW')]
# 10878
# [('bpFrom', 'SCHL'), ('bpTo', 'SCHL')]
# 233
# [('bpFrom', 'SCHL'), ('bpTo', 'SCHL')]
# 596
# [('bpFrom', 'KLW'), ('bpTo', 'MELH')]
# 6039
# [('bpFrom', 'ZWOL'), ('bpTo', 'ZWOL')]
# 233
# [('bpFrom', 'TW'), ('bpTo', 'TW')]
# 1080
# [('bpFrom', 'ZSTH'), ('bpTo', 'ZTB')]
# 233
# [('bpFrom', 'ZSTH'), ('bpTo', 'ZTB')]
# 15111
# [('bpFrom', 'KUES'), ('bpTo', 'RW')]
# 6039
# [('bpFrom', 'ERLB'), ('bpTo', 'ERLB')]
# 2410
# [('bpFrom', 'NID'), ('bpTo', 'LIN')]
# 535
# [('bpFrom', 'GLB'), ('bpTo', 'GLB')]
# 475
# [('bpFrom', 'HRD'), ('bpTo', 'HRD')]
# 6039
# [('bpFrom', 'FMS'), ('bpTo', 'FMS')]
# 12087
# [('bpFrom', 'ZUE'), ('bpTo', 'CH')]
# 536
# [('bpFrom', 'FMS'), ('bpTo', 'FMS')]
# 2954
# [('bpFrom', 'OP'), ('bpTo', 'ZFH')]
# 717
# [('bpFrom', 'OP'), ('bpTo', 'ZFH')]
# 112
# [('bpFrom', 'ZFH'), ('bpTo', 'DORF')]
# 24183
# [('bpFrom', 'WS'), ('bpTo', 'HUER')]
# 4829
# [('bpFrom', 'W'), ('bpTo', 'W')]
# 596
# [('bpFrom', 'HUER'), ('bpTo', 'HUER')]
# 6281
# [('bpFrom', 'FF'), ('bpTo', 'FF')]
# 3015
# [('bpFrom', 'MUEL'), ('bpTo', 'MUEL')]
# 6039
# [('bpFrom', 'SLG'), ('bpTo', 'WF')]
# 10272
# [('bpFrom', 'WGR'), ('bpTo', 'SIR')]
# 2410
# [('bpFrom', 'GSS'), ('bpTo', 'GSS')]
# 6039
# [('bpFrom', 'SGWI'), ('bpTo', 'SGWI')]
# 8458
# [('bpFrom', 'WGR'), ('bpTo', 'SG')]
# 2410
# [('bpFrom', 'GUN'), ('bpTo', 'GSS')]
# 6039
# [('bpFrom', 'GSS'), ('bpTo', 'SLG')]
# 475
# [('bpFrom', 'HGT'), ('bpTo', 'HGT')]
# 4527
# [('bpFrom', 'WTOE'), ('bpTo', 'EMB')]
# 10878
# [('bpFrom', 'UST'), ('bpTo', 'AAT')]
# 354
# [('bpFrom', 'UST'), ('bpTo', 'UST')]
# 6039
# [('bpFrom', 'EF'), ('bpTo', 'WZ')]
# 12087
# [('bpFrom', 'SEU'), ('bpTo', 'EW')]
# 15111
# [('bpFrom', 'FT'), ('bpTo', 'FT')]
# 2410
# [('bpFrom', 'KR'), ('bpTo', 'KR')]
# 474
# [('bpFrom', 'EW'), ('bpTo', 'EW')]
# 475
# [('bpFrom', 'STR'), ('bpTo', 'EZ')]
# 12087
# [('bpFrom', 'TAEN'), ('bpTo', 'TAEN')]
# 475
# [('bpFrom', 'SHAU'), ('bpTo', 'LENG')]
# 717
# [('bpFrom', 'UZ'), ('bpTo', 'KAB')]
# 9063
# [('bpFrom', 'LUET'), ('bpTo', 'LUET')]
# 112
# [('bpFrom', 'IM'), ('bpTo', 'BRU')]
# 233
# [('bpFrom', 'GD'), ('bpTo', 'GD')]
# 4950
# [('bpFrom', 'GD'), ('bpTo', 'SCHW')]
# 2592
# [('bpFrom', 'GOE'), ('bpTo', 'GOE')]
# 4406
# [('bpFrom', 'AI'), ('bpTo', 'AI')]
# 2108
# [('bpFrom', 'FA'), ('bpTo', 'FA')]
# 2108
# [('bpFrom', 'LAV'), ('bpTo', 'LAV')]
# 51
# [('bpFrom', 'GIDI'), ('bpTo', 'CAST')]
# 777
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 596
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 1563
# [('bpFrom', 'VEZB'), ('bpTo', 'CAP')]
# 12087
# [('bpFrom', 'LG'), ('bpTo', 'LG')]
# 4769
# [('bpFrom', 'MDE'), ('bpTo', 'MDE')]
# 2108
# [('bpFrom', 'GREL'), ('bpTo', 'DUG')]
# 2894
# [('bpFrom', 'TH'), ('bpTo', 'TH')]
# 1564
# [('bpFrom', 'WBOL'), ('bpTo', 'WBOL')]
# 3015
# [('bpFrom', 'BET'), ('bpTo', 'BET')]
# 3015
# [('bpFrom', 'SEL'), ('bpTo', 'SEL')]
# 16804
# [('bpFrom', 'LTH'), ('bpTo', 'HB')]
# 2894
# [('bpFrom', 'ZOL'), ('bpTo', 'ZOL')]
# 535
# [('bpFrom', 'LN'), ('bpTo', 'SCHH')]
# 2894
# [('bpFrom', 'LN'), ('bpTo', 'LN')]
# 7248
# [('bpFrom', 'DAG'), ('bpTo', 'DAG')]
# 6039
# [('bpFrom', 'ZF'), ('bpTo', 'RBG')]
# 535
# [('bpFrom', 'OBK'), ('bpTo', 'OBK')]
# 5555
# [('bpFrom', 'LZ'), ('bpTo', 'LZ')]
# 9365
# [('bpFrom', 'SAF'), ('bpTo', 'SAF')]
# 6281
# [('bpFrom', 'DK'), ('bpTo', 'DK')]
# 6281
# [('bpFrom', 'DKRB'), ('bpTo', 'DKRB')]
# 20192
# [('bpFrom', 'RU'), ('bpTo', 'KLW')]
# 656
# [('bpFrom', 'AA'), ('bpTo', 'RU')]
# 3136
# [('bpFrom', 'OL'), ('bpTo', 'OL')]
# 15716
# [('bpFrom', 'GSK'), ('bpTo', 'KUE')]
# 3136
# [('bpFrom', 'BG'), ('bpTo', 'TG')]
# 3136
# [('bpFrom', 'TG'), ('bpTo', 'TG')]
# 3136
# [('bpFrom', 'TG'), ('bpTo', 'TG')]
# 112
# [('bpFrom', 'LP'), ('bpTo', 'LP')]
# 1564
# [('bpFrom', 'GEAP'), ('bpTo', 'CHNE')]
# 6281
# [('bpFrom', 'GE'), ('bpTo', 'GE')]
# 233
# [('bpFrom', 'MOR'), ('bpTo', 'STP')]
# 21764
# [('bpFrom', 'LS'), ('bpTo', 'LS')]
# 3136
# [('bpFrom', 'ROS'), ('bpTo', 'ROS')]
# 3136
# [('bpFrom', 'FRI'), ('bpTo', 'FRI')]
# 3257
# [('bpFrom', 'ROC'), ('bpTo', 'AIG')]
# 12571
# [('bpFrom', 'ST'), ('bpTo', 'AIG')]
# 3136
# [('bpFrom', 'CORN'), ('bpTo', 'CORN')]
# 6039
# [('bpFrom', 'ZSEB'), ('bpTo', 'WE')]
# 1805
# [('bpFrom', 'ZSEB'), ('bpTo', 'WUER')]
# 18135
# [('bpFrom', 'WUER'), ('bpTo', 'WUER')]
# 2410
# [('bpFrom', 'DT'), ('bpTo', 'DT')]
# 6039
# [('bpFrom', 'ZAS'), ('bpTo', 'ZAS')]
# 3136
# [('bpFrom', 'WE'), ('bpTo', 'WE')]
# 898
# [('bpFrom', 'KLW'), ('bpTo', 'WE')]
# 6039
# [('bpFrom', 'TW'), ('bpTo', 'TW')]
# 6039
# [('bpFrom', 'SIB'), ('bpTo', 'SCBU')]
# 233
# [('bpFrom', 'PF'), ('bpTo', 'PF')]
# 6039
# [('bpFrom', 'ZOER'), ('bpTo', 'ZOER')]
# 4224
# [('bpFrom', 'GLB'), ('bpTo', 'BUE')]
# 2410
# [('bpFrom', 'BUE'), ('bpTo', 'BUE')]
# 51
# [('bpFrom', 'RZ'), ('bpTo', 'RZ')]
# 4829
# [('bpFrom', 'UNT'), ('bpTo', 'UNT')]
# 4829
# [('bpFrom', 'UNT'), ('bpTo', 'MH')]
# 3015
# [('bpFrom', 'FMS'), ('bpTo', 'FMS')]
# 293
# [('bpFrom', 'CH'), ('bpTo', 'CH')]
# 6039
# [('bpFrom', 'ZSTH'), ('bpTo', 'ZSTH')]
# 6039
# [('bpFrom', 'WS'), ('bpTo', 'WS')]
# 12087
# [('bpFrom', 'KL'), ('bpTo', 'KL')]
# 8458
# [('bpFrom', 'W'), ('bpTo', 'WF')]
# 12087
# [('bpFrom', 'OWT'), ('bpTo', 'OWT')]
# 6039
# [('bpFrom', 'WF'), ('bpTo', 'WF')]
# 596
# [('bpFrom', 'SLG'), ('bpTo', 'RH')]
# 3015
# [('bpFrom', 'WIL'), ('bpTo', 'WIL')]
# 6039
# [('bpFrom', 'WIL'), ('bpTo', 'WIL')]
# 2410
# [('bpFrom', 'SGBR'), ('bpTo', 'SGBR')]
# 8458
# [('bpFrom', 'SG'), ('bpTo', 'SG')]
# 12087
# [('bpFrom', 'SG'), ('bpTo', 'SG')]
# 15111
# [('bpFrom', 'W'), ('bpTo', 'SG')]
# 6039
# [('bpFrom', 'RS'), ('bpTo', 'RS')]
# 6039
# [('bpFrom', 'SMG'), ('bpTo', 'SMG')]
# 5494
# [('bpFrom', 'WZ'), ('bpTo', 'WZ')]
# 3015
# [('bpFrom', 'OSS'), ('bpTo', 'OSS')]
# 5131
# [('bpFrom', 'SH'), ('bpTo', 'FT')]
# 716
# [('bpFrom', 'EZ'), ('bpTo', 'EZ')]
# 2410
# [('bpFrom', 'WIL'), ('bpTo', 'BRO')]
# 112
# [('bpFrom', 'KRB'), ('bpTo', 'KRB')]
# 474
# [('bpFrom', 'BERG'), ('bpTo', 'SHAU')]
# 1503
# [('bpFrom', 'BRU'), ('bpTo', 'BRU')]
# 293
# [('bpFrom', 'ER'), ('bpTo', 'ER')]
# 293
# [('bpFrom', 'ER'), ('bpTo', 'ER')]
# 172
# [('bpFrom', 'AP'), ('bpTo', 'AP')]
# 2350
# [('bpFrom', 'AP'), ('bpTo', 'AP')]
# 9426
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 1926
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 777
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 5978
# [('bpFrom', 'VEZB'), ('bpTo', 'CAP')]
# 233
# [('bpFrom', 'BAA'), ('bpTo', 'ZG')]
# 20313
# [('bpFrom', 'RUB'), ('bpTo', 'WCH')]
# 17047
# [('bpFrom', 'OST'), ('bpTo', 'RUB')]
# 2894
# [('bpFrom', 'UTI'), ('bpTo', 'TH')]
# 1019
# [('bpFrom', 'HAE'), ('bpTo', 'HAE')]
# 1563
# [('bpFrom', 'SW'), ('bpTo', 'SW')]
# 3015
# [('bpFrom', 'LEN'), ('bpTo', 'LEN')]
# 15111
# [('bpFrom', 'SO'), ('bpTo', 'WANZ')]
# 7870
# [('bpFrom', 'LTH'), ('bpTo', 'LTH')]
# 2894
# [('bpFrom', 'OL'), ('bpTo', 'LTH')]
# 717
# [('bpFrom', 'LN'), ('bpTo', 'SCHH')]
# 9063
# [('bpFrom', 'OL'), ('bpTo', 'ABO')]
# 2108
# [('bpFrom', 'ABO'), ('bpTo', 'ABO')]
# 535
# [('bpFrom', 'SS'), ('bpTo', 'SS')]
# 2894
# [('bpFrom', 'FMUE'), ('bpTo', 'EBR')]
# 3136
# [('bpFrom', 'OL'), ('bpTo', 'OL')]
# 3136
# [('bpFrom', 'BS'), ('bpTo', 'BS')]
# 15716
# [('bpFrom', 'LB'), ('bpTo', 'HU')]
# 4830
# [('bpFrom', 'SCOE'), ('bpTo', 'SCOE')]
# 3136
# [('bpFrom', 'DK'), ('bpTo', 'AA')]
# 7854
# [('bpFrom', 'FMUE'), ('bpTo', 'IM')]
# 2350
# [('bpFrom', 'IM'), ('bpTo', 'IM')]
# 3015
# [('bpFrom', 'LB'), ('bpTo', 'RU')]
# 3136
# [('bpFrom', 'AA'), ('bpTo', 'RU')]
# 2350
# [('bpFrom', 'IM'), ('bpTo', 'IM')]
# 3136
# [('bpFrom', 'LP'), ('bpTo', 'CHNE')]
# 233
# [('bpFrom', 'MOR'), ('bpTo', 'STP')]
# 353
# [('bpFrom', 'DEN'), ('bpTo', 'REN')]
# 2410
# [('bpFrom', 'LS'), ('bpTo', 'CVN')]
# 2410
# [('bpFrom', 'LS'), ('bpTo', 'CVN')]
# 3136
# [('bpFrom', 'ROS'), ('bpTo', 'ROS')]
# 3136
# [('bpFrom', 'NESE'), ('bpTo', 'NESE')]
# 172
# [('bpFrom', 'SBL'), ('bpTo', 'CORN')]
# 3136
# [('bpFrom', 'LHE'), ('bpTo', 'LHE')]
# 6039
# [('bpFrom', 'HGO'), ('bpTo', 'HGO')]
# 6039
# [('bpFrom', 'ZWD'), ('bpTo', 'ZWD')]
# 475
# [('bpFrom', 'DT'), ('bpTo', 'DT')]
# 15111
# [('bpFrom', 'TW'), ('bpTo', 'TW')]
# 6039
# [('bpFrom', 'PF'), ('bpTo', 'ALTD')]
# 6039
# [('bpFrom', 'ZWIE'), ('bpTo', 'ZWIE')]
# 6039
# [('bpFrom', 'HG'), ('bpTo', 'HG')]
# 3136
# [('bpFrom', 'ZWIE'), ('bpTo', 'ZWOL')]
# 838
# [('bpFrom', 'PF'), ('bpTo', 'LA')]
# 30231
# [('bpFrom', 'ZSTH'), ('bpTo', 'ZSTH')]
# 293
# [('bpFrom', 'ZTB'), ('bpTo', 'ZTB')]
# 9063
# [('bpFrom', 'HERL'), ('bpTo', 'ML')]
# 6039
# [('bpFrom', 'MAEN'), ('bpTo', 'MAEN')]
# 2410
# [('bpFrom', 'UER'), ('bpTo', 'UER')]
# 2410
# [('bpFrom', 'FB'), ('bpTo', 'FB')]
# 6039
# [('bpFrom', 'LU'), ('bpTo', 'LIN')]
# 1200
# [('bpFrom', 'GLB'), ('bpTo', 'GLB')]
# 898
# [('bpFrom', 'GLB'), ('bpTo', 'GLB')]
# 7853
# [('bpFrom', 'SHRB'), ('bpTo', 'SHRB')]
# 2410
# [('bpFrom', 'SH'), ('bpTo', 'SH')]
# 6039
# [('bpFrom', 'MELS'), ('bpTo', 'MELS')]
# 6039
# [('bpFrom', 'WN'), ('bpTo', 'WN')]
# 15111
# [('bpFrom', 'LQ'), ('bpTo', 'LQ')]
# 30231
# [('bpFrom', 'ZSTH'), ('bpTo', 'ZTB')]
# 293
# [('bpFrom', 'NEGW'), ('bpTo', 'NEGW')]
# 6039
# [('bpFrom', 'STET'), ('bpTo', 'STET')]
# 6039
# [('bpFrom', 'DTL'), ('bpTo', 'DTL')]
# 12087
# [('bpFrom', 'EF'), ('bpTo', 'EF')]
# 12087
# [('bpFrom', 'EF'), ('bpTo', 'EF')]
# 3922
# [('bpFrom', 'KE'), ('bpTo', 'KE')]
# 3015
# [('bpFrom', 'ZWIP'), ('bpTo', 'ZWIP')]
# 3136
# [('bpFrom', 'ZWIP'), ('bpTo', 'ZWIP')]
# 6039
# [('bpFrom', 'OP'), ('bpTo', 'OP')]
# 6039
# [('bpFrom', 'OP'), ('bpTo', 'OP')]
# 9063
# [('bpFrom', 'WD'), ('bpTo', 'ISL')]
# 3015
# [('bpFrom', 'SLG'), ('bpTo', 'SLG')]
# 172
# [('bpFrom', 'WF'), ('bpTo', 'WF')]
# 9063
# [('bpFrom', 'OA'), ('bpTo', 'RH')]
# 6039
# [('bpFrom', 'WGR'), ('bpTo', 'WGR')]
# 233
# [('bpFrom', 'EL'), ('bpTo', 'EL')]
# 233
# [('bpFrom', 'SCHZ'), ('bpTo', 'SCHZ')]
# 2108
# [('bpFrom', 'SG'), ('bpTo', 'SMG')]
# 1805
# [('bpFrom', 'ORT'), ('bpTo', 'ALT')]
# 3136
# [('bpFrom', 'TRUE'), ('bpTo', 'BU')]
# 6039
# [('bpFrom', 'BU'), ('bpTo', 'BU')]
# 3015
# [('bpFrom', 'PFU'), ('bpTo', 'WWUE')]
# 4830
# [('bpFrom', 'UST'), ('bpTo', 'UST')]
# 3620
# [('bpFrom', 'GIB'), ('bpTo', 'WL')]
# 12087
# [('bpFrom', 'OSS'), ('bpTo', 'OSS')]
# 6039
# [('bpFrom', 'STR'), ('bpTo', 'STR')]
# 1200
# [('bpFrom', 'EW'), ('bpTo', 'EW')]
# 6039
# [('bpFrom', 'RH'), ('bpTo', 'RS')]
# 172
# [('bpFrom', 'BROA'), ('bpTo', 'WIL')]
# 112
# [('bpFrom', 'TOA'), ('bpTo', 'TOA')]
# 112
# [('bpFrom', 'IM'), ('bpTo', 'BRU')]
# 6281
# [('bpFrom', 'IM'), ('bpTo', 'GD')]
# 172
# [('bpFrom', 'GD'), ('bpTo', 'GD')]
# 293
# [('bpFrom', 'SCHW'), ('bpTo', 'SCHW')]
# 112
# [('bpFrom', 'BRU'), ('bpTo', 'AL')]
# 1563
# [('bpFrom', 'BRU'), ('bpTo', 'SK')]
# 293
# [('bpFrom', 'ER'), ('bpTo', 'ER')]
# 1806
# [('bpFrom', 'AS'), ('bpTo', 'AS')]
# 354
# [('bpFrom', 'AP'), ('bpTo', 'AP')]
# 475
# [('bpFrom', 'GIDI'), ('bpTo', 'GIDI')]
# 354
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 2531
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 4769
# [('bpFrom', 'MDE'), ('bpTo', 'MDE')]
# 172
# [('bpFrom', 'LG'), ('bpTo', 'LG')]
# 233
# [('bpFrom', 'CHI'), ('bpTo', 'CHI')]
# 18800
# [('bpFrom', 'BAA'), ('bpTo', 'BAA')]
# 18800
# [('bpFrom', 'ZG'), ('bpTo', 'BAA')]
# 233
# [('bpFrom', 'BAA'), ('bpTo', 'ZG')]
# 1019
# [('bpFrom', 'ZG'), ('bpTo', 'ZG')]
# 112
# [('bpFrom', 'ZG'), ('bpTo', 'GD')]
# 33134
# [('bpFrom', 'BN'), ('bpTo', 'BN')]
# 699
# [('bpFrom', 'KZ'), ('bpTo', 'LY')]
# 535
# [('bpFrom', 'DN'), ('bpTo', 'DN')]
# 3015
# [('bpFrom', 'OLH'), ('bpTo', 'OLH')]
# 10877
# [('bpFrom', 'OL'), ('bpTo', 'OL')]
# 15716
# [('bpFrom', 'WKD'), ('bpTo', 'ABO')]
# 7248
# [('bpFrom', 'BN'), ('bpTo', 'BWY')]
# 2894
# [('bpFrom', 'ZAE'), ('bpTo', 'BOW')]
# 9063
# [('bpFrom', 'ZF'), ('bpTo', 'EBR')]
# 3136
# [('bpFrom', 'BS'), ('bpTo', 'BS')]
# 4527
# [('bpFrom', 'ZF'), ('bpTo', 'SAF')]
# 15716
# [('bpFrom', 'SUHR'), ('bpTo', 'OEF')]
# 20192
# [('bpFrom', 'LB'), ('bpTo', 'LB')]
# 3922
# [('bpFrom', 'SINS'), ('bpTo', 'SINS')]
# 5978
# [('bpFrom', 'MI'), ('bpTo', 'BNZ')]
# 5978
# [('bpFrom', 'MI'), ('bpTo', 'BNZ')]
# 2894
# [('bpFrom', 'EBI'), ('bpTo', 'EBI')]
# 112
# [('bpFrom', 'EBI'), ('bpTo', 'EBI')]
# 6281
# [('bpFrom', 'GE'), ('bpTo', 'GE')]
# 15897
# [('bpFrom', 'MOR'), ('bpTo', 'MOR')]
# 9426
# [('bpFrom', 'DEN'), ('bpTo', 'MOR')]
# 656
# [('bpFrom', 'REN'), ('bpTo', 'DEN')]
# 596
# [('bpFrom', 'LS'), ('bpTo', 'CVN')]
# 3136
# [('bpFrom', 'TUR'), ('bpTo', 'TUR')]
# 3136
# [('bpFrom', 'CORN'), ('bpTo', 'CORN')]
# 8700
# [('bpFrom', 'MOU'), ('bpTo', 'MOU')]
# 4527
# [('bpFrom', 'WE'), ('bpTo', 'WE')]
# 6039
# [('bpFrom', 'ZUE'), ('bpTo', 'ZUE')]
# 293
# [('bpFrom', 'ZAS'), ('bpTo', 'ZAS')]
# 15111
# [('bpFrom', 'WAE'), ('bpTo', 'WAE')]
# 4829
# [('bpFrom', 'PF'), ('bpTo', 'PF')]
# 717
# [('bpFrom', 'RG'), ('bpTo', 'BIL')]
# 3681
# [('bpFrom', 'RUES'), ('bpTo', 'RUES')]
# 9063
# [('bpFrom', 'ZB'), ('bpTo', 'ZB')]
# 2410
# [('bpFrom', 'STAE'), ('bpTo', 'STAE')]
# 3015
# [('bpFrom', 'UET'), ('bpTo', 'UET')]
# 6039
# [('bpFrom', 'SH'), ('bpTo', 'SH')]
# 2410
# [('bpFrom', 'GF'), ('bpTo', 'GF')]
# 233
# [('bpFrom', 'EGL'), ('bpTo', 'HUEW')]
# 233
# [('bpFrom', 'RZ'), ('bpTo', 'RZ')]
# 24183
# [('bpFrom', 'KE'), ('bpTo', 'W')]
# 10877
# [('bpFrom', 'OP'), ('bpTo', 'KL')]
# 9063
# [('bpFrom', 'KL'), ('bpTo', 'KL')]
# 6039
# [('bpFrom', 'RIK'), ('bpTo', 'RIK')]
# 6039
# [('bpFrom', 'ISL'), ('bpTo', 'ISL')]
# 354
# [('bpFrom', 'WF'), ('bpTo', 'WF')]
# 1503
# [('bpFrom', 'BGL'), ('bpTo', 'SLG')]
# 233
# [('bpFrom', 'SLG'), ('bpTo', 'SLG')]
# 9063
# [('bpFrom', 'WGR'), ('bpTo', 'WGR')]
# 7854
# [('bpFrom', 'WGR'), ('bpTo', 'WGR')]
# 5132
# [('bpFrom', 'GSS'), ('bpTo', 'GSS')]
# 233
# [('bpFrom', 'SGF'), ('bpTo', 'SGF')]
# 2410
# [('bpFrom', 'RTH'), ('bpTo', 'ORT')]
# 716
# [('bpFrom', 'ARN'), ('bpTo', 'ARN')]
# 13901
# [('bpFrom', 'HET'), ('bpTo', 'SH')]
# 293
# [('bpFrom', 'AN'), ('bpTo', 'AN')]
# 6039
# [('bpFrom', 'BUB'), ('bpTo', 'BUB')]
# 9063
# [('bpFrom', 'FET'), ('bpTo', 'WZ')]
# 717
# [('bpFrom', 'SH'), ('bpTo', 'FT')]
# 4829
# [('bpFrom', 'STR'), ('bpTo', 'STR')]
# 293
# [('bpFrom', 'MAM'), ('bpTo', 'MAM')]
# 475
# [('bpFrom', 'BERG'), ('bpTo', 'BERG')]
# 293
# [('bpFrom', 'ER'), ('bpTo', 'ER')]
# 172
# [('bpFrom', 'GU'), ('bpTo', 'GU')]
# 535
# [('bpFrom', 'GOE'), ('bpTo', 'GOE')]
# 233
# [('bpFrom', 'SORD'), ('bpTo', 'SORD')]
# 172
# [('bpFrom', 'LAV'), ('bpTo', 'LAV')]
# 51
# [('bpFrom', 'POLN'), ('bpTo', 'GIDI')]
# 9123
# [('bpFrom', 'CAST'), ('bpTo', 'CAST')]
# 2047
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 5978
# [('bpFrom', 'VEZB'), ('bpTo', 'CAP')]
# 51
# [('bpFrom', 'LG'), ('bpTo', 'LG')]
# 3015
# [('bpFrom', 'LG'), ('bpTo', 'LG')]
# 15655
# [('bpFrom', 'ZG'), ('bpTo', 'ZG')]
# 1321
# [('bpFrom', 'GREL'), ('bpTo', 'DUG')]
# 32952
# [('bpFrom', 'BNBS'), ('bpTo', 'BN')]
# 8942
# [('bpFrom', 'BNBS'), ('bpTo', 'FLM')]
# 2894
# [('bpFrom', 'LY'), ('bpTo', 'LY')]
# 12571
# [('bpFrom', 'OST'), ('bpTo', 'OST')]
# 29626
# [('bpFrom', 'LGUT'), ('bpTo', 'OST')]
# 2894
# [('bpFrom', 'UTI'), ('bpTo', 'KI')]
# 2894
# [('bpFrom', 'ABO'), ('bpTo', 'LGUT')]
# 1019
# [('bpFrom', 'WAA'), ('bpTo', 'WAA')]
# 3015
# [('bpFrom', 'PIE'), ('bpTo', 'PIE')]
# 3015
# [('bpFrom', 'BIM'), ('bpTo', 'BIM')]
# 51
# [('bpFrom', 'WBOL'), ('bpTo', 'WBOL')]
# 2894
# [('bpFrom', 'HB'), ('bpTo', 'RTW')]
# 2894
# [('bpFrom', 'WH'), ('bpTo', 'SCHA')]
# 7733
# [('bpFrom', 'ZF'), ('bpTo', 'ABO')]
# 15111
# [('bpFrom', 'SS'), ('bpTo', 'SS')]
# 9063
# [('bpFrom', 'RBG'), ('bpTo', 'RBG')]
# 1321
# [('bpFrom', 'BS'), ('bpTo', 'OL')]
# 3136
# [('bpFrom', 'BS'), ('bpTo', 'BS')]
# 3136
# [('bpFrom', 'BS'), ('bpTo', 'BS')]
# 24183
# [('bpFrom', 'OEF'), ('bpTo', 'OEF')]
# 15716
# [('bpFrom', 'KK'), ('bpTo', 'OEF')]
# 293
# [('bpFrom', 'LZVH'), ('bpTo', 'MEGZ')]
# 3922
# [('bpFrom', 'MERL'), ('bpTo', 'MERL')]
# 112
# [('bpFrom', 'LZVH'), ('bpTo', 'IM')]
# 3136
# [('bpFrom', 'HDK'), ('bpTo', 'HDK')]
# 4527
# [('bpFrom', 'WO'), ('bpTo', 'WO')]
# 11542
# [('bpFrom', 'FMUE'), ('bpTo', 'ROTS')]
# 3136
# [('bpFrom', 'CL'), ('bpTo', 'MX')]
# 3136
# [('bpFrom', 'VIL'), ('bpTo', 'SM')]
# 3136
# [('bpFrom', 'RAR'), ('bpTo', 'RAR')]
# 2894
# [('bpFrom', 'BR'), ('bpTo', 'STDG')]
# 3136
# [('bpFrom', 'LHE'), ('bpTo', 'LHE')]
# 3136
# [('bpFrom', 'BU'), ('bpTo', 'W')]
# 4225
# [('bpFrom', 'SBG'), ('bpTo', 'SBG')]
# 6039
# [('bpFrom', 'KLW'), ('bpTo', 'KLW')]
# 10878
# [('bpFrom', 'DT'), ('bpTo', 'DT')]
# 10878
# [('bpFrom', 'ZAS'), ('bpTo', 'ZAS')]
# 3015
# [('bpFrom', 'KLW'), ('bpTo', 'MELH')]
# 9063
# [('bpFrom', 'SIB'), ('bpTo', 'SIB')]
# 6039
# [('bpFrom', 'STAE'), ('bpTo', 'STAE')]
# 353
# [('bpFrom', 'FB'), ('bpTo', 'RW')]
# 233
# [('bpFrom', 'HERL'), ('bpTo', 'HERL')]
# 1806
# [('bpFrom', 'WIN'), ('bpTo', 'HERL')]
# 474
# [('bpFrom', 'UER'), ('bpTo', 'UER')]
# 1805
# [('bpFrom', 'RW'), ('bpTo', 'BLU')]
# 1442
# [('bpFrom', 'HRD'), ('bpTo', 'ZOER')]
# 4224
# [('bpFrom', 'BUE'), ('bpTo', 'EGL')]
# 4527
# [('bpFrom', 'BUE'), ('bpTo', 'BUE')]
# 354
# [('bpFrom', 'NH'), ('bpTo', 'NH')]
# 3015
# [('bpFrom', 'WN'), ('bpTo', 'WN')]
# 3015
# [('bpFrom', 'MOLS'), ('bpTo', 'UNT')]
# 6039
# [('bpFrom', 'LQ'), ('bpTo', 'LQ')]
# 24183
# [('bpFrom', 'BSD'), ('bpTo', 'BSD')]
# 6039
# [('bpFrom', 'BSD'), ('bpTo', 'BSD')]
# 6039
# [('bpFrom', 'SG'), ('bpTo', 'SG')]
# 15111
# [('bpFrom', 'SG'), ('bpTo', 'SMG')]
# 6039
# [('bpFrom', 'RS'), ('bpTo', 'RSST')]
# 6039
# [('bpFrom', 'RCK'), ('bpTo', 'RCK')]
# 6039
# [('bpFrom', 'SEV'), ('bpTo', 'TRUE')]
# 474
# [('bpFrom', 'BZN'), ('bpTo', 'BZN')]
# 1503
# [('bpFrom', 'WZ'), ('bpTo', 'KN')]
# 12087
# [('bpFrom', 'SEU'), ('bpTo', 'DIH')]
# 6039
# [('bpFrom', 'OWT'), ('bpTo', 'STR')]
# 12087
# [('bpFrom', 'OWT'), ('bpTo', 'SEU')]
# 6039
# [('bpFrom', 'ARB'), ('bpTo', 'HN')]
# 172
# [('bpFrom', 'WF'), ('bpTo', 'KHF')]
# 112
# [('bpFrom', 'BRU'), ('bpTo', 'AL')]
# 1019
# [('bpFrom', 'FL'), ('bpTo', 'FL')]
# 2289
# [('bpFrom', 'RYN'), ('bpTo', 'RYN')]
# 1806
# [('bpFrom', 'ER'), ('bpTo', 'ER')]
# 2471
# [('bpFrom', 'BO'), ('bpTo', 'BO')]
# 233
# [('bpFrom', 'BO'), ('bpTo', 'BO')]
# 2289
# [('bpFrom', 'BO'), ('bpTo', 'BO')]
# 172
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 233
# [('bpFrom', 'BEL'), ('bpTo', 'GIU')]
# 233
# [('bpFrom', 'CHI'), ('bpTo', 'CHI')]
# 9305
# [('bpFrom', 'CD'), ('bpTo', 'CD')]
# 9296
# [('bpFrom', 'CD'), ('bpTo', 'CD')]
# 7309
# [('bpFrom', 'CHAM'), ('bpTo', 'CHAM')]
# 112
# [('bpFrom', 'ZG'), ('bpTo', 'GD')]
# 6281
# [('bpFrom', 'GREL'), ('bpTo', 'DUG')]
# 1321
# [('bpFrom', 'OL'), ('bpTo', 'BI')]
# 1019
# [('bpFrom', 'OB'), ('bpTo', 'OB')]
# 777
# [('bpFrom', 'LUT'), ('bpTo', 'LUT')]
# 6281
# [('bpFrom', 'SO'), ('bpTo', 'SW')]
# 233
# [('bpFrom', 'OEN'), ('bpTo', 'WAA')]
# 3136
# [('bpFrom', 'OLH'), ('bpTo', 'OLH')]
# 3136
# [('bpFrom', 'OLH'), ('bpTo', 'SO')]
# 5736
# [('bpFrom', 'HB'), ('bpTo', 'LTH')]
# 2894
# [('bpFrom', 'LTH'), ('bpTo', 'HB')]
# 1019
# [('bpFrom', 'LN'), ('bpTo', 'SCHH')]
# 14203
# [('bpFrom', 'ZF'), ('bpTo', 'ZF')]
# 3317
# [('bpFrom', 'EBR'), ('bpTo', 'EBR')]
# 2894
# [('bpFrom', 'LZ'), ('bpTo', 'EBR')]
# 4951
# [('bpFrom', 'EBR'), ('bpTo', 'FMUE')]
# 2894
# [('bpFrom', 'LZ'), ('bpTo', 'LZ')]
# 3136
# [('bpFrom', 'OL'), ('bpTo', 'OL')]
# 3136
# [('bpFrom', 'PR'), ('bpTo', 'FRE')]
# 15716
# [('bpFrom', 'SAF'), ('bpTo', 'WAST')]
# 9426
# [('bpFrom', 'OL'), ('bpTo', 'OL')]
# 112
# [('bpFrom', 'MEG'), ('bpTo', 'MEG')]
# 3136
# [('bpFrom', 'OTH'), ('bpTo', 'OI')]
# 6039
# [('bpFrom', 'RK'), ('bpTo', 'IM')]
