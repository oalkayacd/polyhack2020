# %%
import pandas as pd
from datetime import datetime
from datetime import time

# %%
geoshape = pd.read_csv('id_geoshape_copy.csv') #geoshape
construction = pd.read_csv('construction-site_copy.xls.csv') #congestion

# %%
construction.loc[geoshape.index.tolist(),"date"]
# Out:
#                               Region                              project  \
# 0                                RWT  Puidoux - Palézieux  : Wako lot 2.1
# 1                                RWT             Palézieux : Wako lot 2.2
# 2    ? : ne correspond pas à Railsys                                  NaN
# 3                                RWT                 Viaduc de la Paudèze
# 4                                RWT               MX-TER, PS Rue d'Etraz
# ..                               ...                                  ...
# 440                              RME                                  NaN
# 441                              RME                                  NaN
# 442                              RME                                  NaN
# 443                              RME            SO-SW, Ersatz Aarebrücken
# 444                              RME                  OEN=NB, Gl. 104-556
#
#     bp_from bp_to  km from   km to  distance  \
# ...
