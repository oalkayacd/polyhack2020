# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from keplergl import KeplerGl
import pandas as pd

# %%
preset_config = {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [
        {
          "dataId": [
            "data_special_trains"
          ],
          "id": "4suee6zn7",
          "name": [
            "epoch"
          ],
          "type": "timeRange",
          "value": [
            1525335834000,
            1533437501000
          ],
          "enlarged": True,
          "plotType": "histogram",
          "yAxis": None
        },
        {
          "dataId": [
            "data_construction"
          ],
          "id": "0frps9il",
          "name": [
            "start"
          ],
          "type": "timeRange",
          "value": [
            1583585875500,
            1688998518000
          ],
          "enlarged": False,
          "plotType": "histogram",
          "yAxis": None
        }
      ],
      "layers": [
        {
          "id": "utmb418",
          "type": "point",
          "config": {
            "dataId": "data_special_trains",
            "label": "Special Trains",
            "color": [
              53,
              166,
              204
            ],
            "columns": {
              "lat": "geopos_x",
              "lng": "geopos_y",
              "altitude": None
            },
            "isVisible": True,
            "visConfig": {
              "radius": 12,
              "fixedRadius": False,
              "opacity": 1,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "g86t2sh",
          "type": "point",
          "config": {
            "dataId": "data_points",
            "label": "Operation Points",
            "color": [
              77,
              74,
              68
            ],
            "columns": {
              "lat": "geopos_x",
              "lng": "geopos_y",
              "altitude": None
            },
            "isVisible": True,
            "visConfig": {
              "radius": 15,
              "fixedRadius": False,
              "opacity": 1,
              "outline": True,
              "thickness": 2,
              "strokeColor": [
                240,
                237,
                234
              ],
              "colorRange": {
                "name": "Custom Palette",
                "type": "custom",
                "category": "Custom",
                "colors": [
                  "#fc9272",
                  "#fb6a4a",
                  "#ef3b2c",
                  "#cb181d",
                  "#99000d"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                15,
                30
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": []
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": {
              "name": "Importance",
              "type": "integer"
            },
            "sizeScale": "sqrt"
          }
        },
        {
          "id": "1e0c9ak",
          "type": "geojson",
          "config": {
            "dataId": "data_construction",
            "label": "Construction",
            "color": [
              221,
              178,
              124
            ],
            "columns": {
              "geojson": "geshape"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "strokeOpacity": 1,
              "thickness": 3,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "ColorBrewer Paired-6",
                "type": "qualitative",
                "category": "ColorBrewer",
                "colors": [
                  "#a6cee3",
                  "#1f78b4",
                  "#b2df8a",
                  "#33a02c",
                  "#fb9a99",
                  "#e31a1c"
                ]
              },
              "radius": 10,
              "sizeRange": [
                0,
                10
              ],
              "radiusRange": [
                0,
                50
              ],
              "heightRange": [
                0,
                500
              ],
              "elevationScale": 5,
              "stroked": True,
              "filled": False,
              "enable3d": False,
              "wireframe": False
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear",
            "strokeColorField": {
              "name": "reduction of capacity",
              "type": "real"
            },
            "strokeColorScale": "quantile",
            "heightField": None,
            "heightScale": "linear",
            "radiusField": None,
            "radiusScale": "linear"
          }
        },
        {
          "id": "bb2odev",
          "type": "geojson",
          "config": {
            "dataId": "data_zug",
            "label": "Lines",
            "color": [
              221,
              178,
              124
            ],
            "columns": {
              "geojson": "geoshape"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "strokeOpacity": 1,
              "thickness": 1,
              "strokeColor": [
                255,
                254,
                230
              ],
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radius": 10,
              "sizeRange": [
                1,
                8
              ],
              "radiusRange": [
                0,
                50
              ],
              "heightRange": [
                0,
                500
              ],
              "elevationScale": 5,
              "stroked": True,
              "filled": False,
              "enable3d": False,
              "wireframe": False
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": {
              "name": "Anzahl_Zuege",
              "type": "integer"
            },
            "sizeScale": "linear",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "heightField": None,
            "heightScale": "linear",
            "radiusField": None,
            "radiusScale": "linear"
          }
        },
        {
          "id": "kfm8o26",
          "type": "heatmap",
          "config": {
            "dataId": "data_points",
            "label": "Importance Heat Map",
            "color": [
              218,
              112,
              191
            ],
            "columns": {
              "lat": "geopos_x",
              "lng": "geopos_y"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.97,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radius": 65
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "weightField": {
              "name": "Importance",
              "type": "integer"
            },
            "weightScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data_zug": [
              {
                "name": "Strecke_Bezeichnung",
                "format": None
              },
              {
                "name": "BP_Von_Abschnitt",
                "format": None
              },
              {
                "name": "BP_Bis_Abschnitt",
                "format": None
              },
              {
                "name": "Anzahl_Zuege",
                "format": None
              },
              {
                "name": "BPUIC",
                "format": None
              },
              {
                "name": "Strecke",
                "format": None
              },
              {
                "name": "distance",
                "format": None
              }
            ],
            "data_construction": [
              {
                "name": "Unnamed: 0",
                "format": None
              },
              {
                "name": "amount of weeks",
                "format": None
              },
              {
                "name": "date from",
                "format": None
              },
              {
                "name": "date to",
                "format": None
              },
              {
                "name": "end",
                "format": None
              }
            ],
            "data_points": [
              {
                "name": "Abbreviation of the operating point",
                "format": None
              },
              {
                "name": "Name of the operating point",
                "format": None
              },
              {
                "name": "BPUIC",
                "format": None
              },
              {
                "name": "Importance",
                "format": None
              }
            ],
            "data_special_trains": [
              {
                "name": "Unnamed: 0",
                "format": None
              },
              {
                "name": "time",
                "format": None
              },
              {
                "name": "epoch",
                "format": None
              },
              {
                "name": "fahrt_bezeichner",
                "format": None
              },
              {
                "name": "betreiber_name",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 0,
      "dragRotate": False,
      "latitude": 46.60094011527404,
      "longitude": 7.9869425820486635,
      "pitch": 0,
      "zoom": 7.432779615491066,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        9.665468314072013,
        17.18305478057247,
        31.1442867897876
      ],
      "mapStyles": {}
    }
  }
}

# %%
df_zug = pd.read_csv('zugzahlen_w_dist.csv')
df_construction = pd.read_csv('endresult_copy.csv')
df_points = pd.read_csv('operation_points_split_importance.csv')
df_special_t = pd.read_csv('special_trains_w_epoch.csv')

# %%
map_1 = KeplerGl(height=1100, config = preset_config) #also config addable
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map_1.add_data(data=df_zug, name='data_zug')
map_1.add_data(data=df_construction, name='data_construction')
map_1.add_data(data=df_points, name='data_points')
map_1.add_data(data=df_special_t, name='data_special_trains')

# %%
# this will save current map
map_1.save_to_html(file_name='map_w_interaction.html')

# this will save map with the interaction panel disabled
map_1.save_to_html(file_name='map_read_only.html', read_only=True)
# Out:
# Map saved to map_w_interaction.html!
# Map saved to map_read_only.html!

# %%
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [{'dataId': ['data_special_trains'], 'id'…
