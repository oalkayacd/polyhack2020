# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import math
from math import sin, cos, sqrt, atan2, radians

# %%
zugzahlen = pd.read_csv('zugzahlen_copy.xls.csv')


def calc_dist(lat1, lon1, lat2, lon2):

    # approximate radius of earth in km
    R = 6373.0

    dlon = radians(lon2) - radians(lon1)
    dlat = radians(lat2) - radians(lat1)

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    return distance

# %%
dist = []
for idx, entry in zugzahlen.iterrows():
    d1 = str(entry["geopos_von"])
    d2 = str(entry["geopos_bis"])
    if d1 == 'nan' or d2 == 'nan':
        dist.append(0)
        continue
    d1 = d1.split(',')
    d2 = d2.split(',')
    lat1 = float(d1[0])
    lon1 = float(d1[1])
    lat2 = float(d2[0])
    lon2 = float(d2[1])
    distance = calc_dist(lat1, lon1, lat2, lon2)
    dist.append(distance)

zugzahlen.insert(24,column="distance",value=dist)

# %%
zugzahlen.to_csv('zugzahlen_w_dist.csv')
# Out:
#                    PID     ISB  Strecke           Strecke_Bezeichnung  \
# 0         SBB_ALL_ETOY     SBB        1    Genève Aéroport - Lausanne
# 1          SBB_CEL_MUR     SBB        1    Genève Aéroport - Lausanne
# 2          SBB_COP_FOU     SBB        1    Genève Aéroport - Lausanne
# 3           SBB_CRA_NY     SBB        1    Genève Aéroport - Lausanne
# 4           SBB_CRA_NY     SBB        1    Genève Aéroport - Lausanne
# ...                ...     ...      ...                           ...
# 5068   THURBO_TAEM_KRB  THURBO       80  Wil - Weinfelden - Tägermoos
# 5069   THURBO_TAEN_BTW  THURBO       80  Wil - Weinfelden - Tägermoos
# 5070  THURBO_TAMO_TAEM  THURBO       80  Wil - Weinfelden - Tägermoos
# 5071   THURBO_TOA_TAEN  THURBO       80  Wil - Weinfelden - Tägermoos
# 5072   THURBO_WNOR_BRO  THURBO       80  Wil - Weinfelden - Tägermoos
#
#      Strecke_Art BP_Von_Abschnitt BP_Von_Abschnitt_Bezeichnung  \
# 0        STRECKE              ALL                      Allaman
# 1        STRECKE              CEL                      Céligny
# 2        STRECKE              COP                       Coppet
# 3        STRECKE              CRA                        Crans
# 4        STRECKE              CRA                        Crans
# ...          ...              ...                          ...
# 5068     STRECKE             TAEM              Tägerwilen Dorf
# 5069     STRECKE             TAEN                   Tägerschen
# 5070     STRECKE             TAMO             Tägermoos (Abzw)
# 5071     STRECKE              TOA           Tobel-Affeltrangen
# 5072     STRECKE             WNOR                     Wil Nord
#
#      BP_Bis_Abschnitt BP_Bis_Abschnitt_Bezeichnung  In_Richtung  ...  \
# 0                ETOY                         Etoy        False  ...
# 1                 MUR                 Murat (diag)        False  ...
# 2                 FOU                       Founex        False  ...
# 3                  NY                         Nyon         True  ...
# 4                  NY                         Nyon        False  ...
# ...               ...                          ...          ...  ...
# 5068              KRB         Kreuzlingen Bernrain        False  ...
# 5069              BTW                   Bettwiesen        False  ...
# 5070             TAEM              Tägerwilen Dorf        False  ...
# 5071             TAEN                   Tägerschen         True  ...
# 5072              BRO                 Bronschhofen        False  ...
#
#      Didok Nummer      Name Haltestelle  \
# 0          1042.0                  Etoy
# 1          1029.0          Murat (diag)
# 2          1016.0                Founex
# 3          1030.0                  Nyon
# 4          1030.0                  Nyon
# ...           ...                   ...
# 5068       6197.0  Kreuzlingen Bernrain
# 5069       6182.0            Bettwiesen
# 5070       6198.0       Tägerwilen Dorf
# 5071       6168.0            Tägerschen
# 5072       6181.0          Bronschhofen
#
#                                                    lod  \
# 0     http://lod.opentransportdata.swiss/didok/8501042
# 1     http://lod.opentransportdata.swiss/didok/8501029
# 2     http://lod.opentransportdata.swiss/didok/8501016
# 3     http://lod.opentransportdata.swiss/didok/8501030
# 4     http://lod.opentransportdata.swiss/didok/8501030
# ...                                                ...
# 5068  http://lod.opentransportdata.swiss/didok/8506197
# 5069  http://lod.opentransportdata.swiss/didok/8506182
# 5070  http://lod.opentransportdata.swiss/didok/8506198
# 5071  http://lod.opentransportdata.swiss/didok/8506168
# 5072  http://lod.opentransportdata.swiss/didok/8506181
#
#                             geopos  tu-nummer                    geopos_von  \
# 0     46.4751727321, 6.42713532969       11.0  6.39969709242, 46.4757535389
# 1     46.3535823538, 6.20634986541       11.0  6.20008722493, 46.3479745705
# 2     46.3287835847, 6.19438330424       11.0  6.18782739372, 46.3173935799
# 3       46.38441894, 6.23596607924       11.0  6.21246417593, 46.3587497583
# 4       46.38441894, 6.23596607924       11.0  6.21246417593, 46.3587497583
# ...                            ...        ...                           ...
# 5068  47.6421145154, 9.16320415414       11.0  9.13955954547, 47.6537211492
# 5069  47.4986213574, 9.02077968719       11.0  9.02479323479, 47.5093638855
# 5070  47.6537211492, 9.13955954547       11.0   9.14964820751, 47.656995045
# 5071  47.5093638855, 9.02479323479       11.0  9.03370938412, 47.5213013698
# 5072  47.4754443436, 9.03467784735       11.0   9.0298999546, 47.4620100277
#
#                         geopos_bis  \
# 0     6.42713532969, 46.4751727321
# 1     6.20634986541, 46.3535823538
# 2     6.19438330424, 46.3287835847
# 3       6.23596607924, 46.38441894
# 4       6.23596607924, 46.38441894
# ...                            ...
# 5068  9.16320415414, 47.6421145154
# 5069  9.02077968719, 47.4986213574
# 5070  9.13955954547, 47.6537211492
# 5071  9.02479323479, 47.5093638855
# 5072  9.03467784735, 47.4754443436
#
#                                                geoshape  \
# 0     {"type": "LineString", "coordinates": [[6.3996...
# 1     {"type": "LineString", "coordinates": [[6.2000...
# 2     {"type": "LineString", "coordinates": [[6.1878...
# 3     {"type": "LineString", "coordinates": [[6.2124...
# 4     {"type": "LineString", "coordinates": [[6.2124...
# ...                                                 ...
# 5068  {"type": "LineString", "coordinates": [[9.1395...
# 5069  {"type": "LineString", "coordinates": [[9.0247...
# 5070  {"type": "LineString", "coordinates": [[9.1496...
# 5071  {"type": "LineString", "coordinates": [[9.0337...
# 5072  {"type": "LineString", "coordinates": [[9.0298...
#
#                       geo_point_2d  distance
# 0     46.4754631355, 6.41341621105  3.052623
# 1     46.3507784622, 6.20321854517  0.933714
# 2     46.3230885823, 6.19110534898  1.457127
# 3     46.3715843491, 6.22421512758  3.867323
# 4     46.3715843491, 6.22421512758  3.867323
# ...                            ...       ...
# 5068  47.6479178323, 9.15138184981  2.908914
# 5069  47.5039926214, 9.02278646099  1.186799
# 5070  47.6553580971, 9.14460387649  1.175461
# 5071  47.5153326276, 9.02925130945  1.576341
# 5072  47.4687271857, 9.03228890098  1.479416
#
# [5073 rows x 25 columns]
