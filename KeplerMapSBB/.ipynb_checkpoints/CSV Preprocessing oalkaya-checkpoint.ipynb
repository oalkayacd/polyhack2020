# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import math
from math import sin, cos, sqrt, atan2, radians
import datetime

# %%
zugzahlen = pd.read_csv('zugzahlen_copy.xls.csv')


def calc_dist(lat1, lon1, lat2, lon2):

    # approximate radius of earth in km
    R = 6373.0

    dlon = radians(lon2) - radians(lon1)
    dlat = radians(lat2) - radians(lat1)

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    return distance

# %%
dist = []
for idx, entry in zugzahlen.iterrows():
    d1 = str(entry["geopos_von"])
    d2 = str(entry["geopos_bis"])
    if d1 == 'nan' or d2 == 'nan':
        dist.append(0)
        continue
    d1 = d1.split(',')
    d2 = d2.split(',')
    lat1 = float(d1[0])
    lon1 = float(d1[1])
    lat2 = float(d2[0])
    lon2 = float(d2[1])
    distance = calc_dist(lat1, lon1, lat2, lon2)
    dist.append(distance)

zugzahlen.insert(24,column="distance",value=dist)

# %%
zugzahlen.to_csv('zugzahlen_w_dist.csv')

# %%
special_trains = pd.read_csv('special-train-polyhack.csv')
col = []
for idx, entry in special_trains.iterrows():
    col.append(datetime.datetime.strptime(entry['time'], '%m/%d/%Y').timestamp())
special_trains.insert(1,column="epoch",value = col)
special_trains.to_csv('special_trains_w_epoch.csv')

# %%
special_trains
# Out:
#             time         epoch fahrt_bezeichner  \
# 0      9/29/2018  1.538172e+09   85:11:2892:006
# 1       9/8/2018  1.536358e+09   85:11:2893:003
# 2      7/14/2019  1.563055e+09  85:11:31344:005
# 3      6/12/2019  1.560290e+09  85:11:31627:004
# 4      9/27/2019  1.569535e+09  85:11:30338:014
# ...          ...           ...              ...
# 42020  10/2/2019  1.569967e+09  85:11:30315:006
# 42021   8/1/2019  1.564610e+09  85:11:31315:009
# 42022  10/3/2019  1.570054e+09  85:11:30346:016
# 42023  8/12/2018  1.534025e+09  85:11:31108:003
# 42024   1/4/2018  1.515020e+09  85:11:31500:001
#
#                         betreiber_name  linien_id    bpuic  \
# 0      Schweizerische Bundesbahnen SBB       2892  8505213
# 1      Schweizerische Bundesbahnen SBB       2893  8505112
# 2      Schweizerische Bundesbahnen SBB      31344  8506000
# 3      Schweizerische Bundesbahnen SBB      31627  8505307
# 4      Schweizerische Bundesbahnen SBB      30338  8504003
# ...
