# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from keplergl import KeplerGl
import pandas as pd

# %%
preset_config = {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [],
      "layers": [
        {
          "id": "g86t2sh",
          "type": "point",
          "config": {
            "dataId": "data_points",
            "label": "Operation Points",
            "color": [
              197,
              21,
              74
            ],
            "columns": {
              "lat": "geopos_x",
              "lng": "geopos_y",
              "altitude": None
            },
            "isVisible": True,
            "visConfig": {
              "radius": 15,
              "fixedRadius": False,
              "opacity": 1,
              "outline": False,
              "thickness": 2,
              "strokeColor": [
                163,
                233,
                236
              ],
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": {
                  "name": "Abbreviation of the operating point",
                  "type": "string"
                },
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "bb2odev",
          "type": "geojson",
          "config": {
            "dataId": "data_zug",
            "label": "Lines",
            "color": [
              221,
              178,
              124
            ],
            "columns": {
              "geojson": "geoshape"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "strokeOpacity": 0.8,
              "thickness": 1,
              "strokeColor": [
                205,
                201,
                191
              ],
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radius": 10,
              "sizeRange": [
                1,
                5
              ],
              "radiusRange": [
                0,
                50
              ],
              "heightRange": [
                0,
                500
              ],
              "elevationScale": 5,
              "stroked": True,
              "filled": False,
              "enable3d": False,
              "wireframe": False
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": {
              "name": "Anzahl_Zuege",
              "type": "integer"
            },
            "sizeScale": "linear",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "heightField": None,
            "heightScale": "linear",
            "radiusField": None,
            "radiusScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data_zug": [
              {
                "name": "Strecke_Bezeichnung",
                "format": None
              },
              {
                "name": "BP_Von_Abschnitt",
                "format": None
              },
              {
                "name": "BP_Bis_Abschnitt",
                "format": None
              },
              {
                "name": "Anzahl_Zuege",
                "format": None
              },
              {
                "name": "Distance",
                "format": None
              },
              {
                "name": "BPUIC",
                "format": None
              },
              {
                "name": "Didok Nummer",
                "format": None
              },
              {
                "name": "Strecke",
                "format": None
              }
            ],
            "data_construction": [
              {
                "name": "bpFrom",
                "format": None
              },
              {
                "name": "bpTo",
                "format": None
              }
            ],
            "data_points": [
              {
                "name": "Abbreviation of the operating point",
                "format": None
              },
              {
                "name": "Name of the operating point",
                "format": None
              },
              {
                "name": "BPUIC",
                "format": None
              },
              {
                "name": "Didok Nummer",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 0,
      "dragRotate": False,
      "latitude": 46.84886684300341,
      "longitude": 7.635996799091492,
      "pitch": 0,
      "zoom": 7.5480589169169505,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        9.665468314072013,
        17.18305478057247,
        31.1442867897876
      ],
      "mapStyles": {}
    }
  }
}

# %%
df_zug = pd.read_csv('zugzahlen_w_dist.csv')
df_construction = pd.read_csv('newConstSite_copy.csv')
df_points = pd.read_csv('operation_points_split.csv')

# %%
map_1 = KeplerGl(height=800, config = preset_config) #also config addable
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map_1.add_data(data=df_zug, name='data_zug')
map_1.add_data(data=df_construction, name='data_construction')
map_1.add_data(data=df_points, name='data_points')

# %%
# this will save current map
map_1.save_to_html(file_name='first_map.html')

# this will save map with the interaction panel disabled
map_1.save_to_html(file_name='first_map.html', read_only=True)
# Out:
# Map saved to first_map.html!
# Map saved to first_map.html!

# %%
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'g86t2sh', 'type': …
